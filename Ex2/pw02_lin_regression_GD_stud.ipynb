# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Linear Regression
#
# Using the rent prices from appartments in Lausanne from PW 02, restricting to the feature living area.
#
# 1. Load data and normalise them - as already implemented in the notebook.
# 2. Reproduce the closed-form solution (of the normal equations) from PW01 (based on pytorch tensors).
# 3. Implement (full batch) GD for linear regression - by using pytorch tensors. Don't use automatic differentiation, but implement the formulas for the gradient explicitly. Make sure that the your GD descent algorithm works correctly by checking that the solution gradually approaches the correct solution as computed in the first step (within numerical precision). Plot estimated MSE cost vs the number of epochs with matplotlib ("loss curve").
# 4. Play with different learning rates. Compare the trainings on the basis of the associated loss curves. Describe what you see and interpret what is going on. What is the maximal learning rate that you can use? What happens when choosing a larger learning rate?
# 5. Solve the linear regression problem by using pytorch's autograd functionality.

# %% [markdown]
# ### 1. Load Data and Normalize

# %%
import pandas as pd
df = pd.read_csv("./data/lausanne-appart.csv")
N  = df.shape[0]
df.head()
# Out:
#    living_area  nb_rooms  rent_price
# 0           69       3.0        1810
# 1           95       3.5        2945
# 2           21       1.5         685
# 3           20       1.0         720
# 4           33       1.5         830

# %%
x0 = df.values[:,0]
x = (x0-np.mean(x0))/np.std(x0)
y0 = df.values[:,2]
y = (y0-np.mean(y0))/np.std(y0)

# %%
plt.plot(x, y,"+")
plt.xlabel("living_area")
plt.ylabel("rent_price")
# Out:
# Text(0, 0.5, 'rent_price')

# %% [markdown]
# ### 2. Linear Model, Normal Equations and Solution
#
# We denote the observed rent by $y_j$ (at time $x_j$) and the model rent by $\hat{y}_j$ we assume
#
# $\qquad \hat{y}_j = \alpha + \beta x_j$
#
# By minimizing the mean squares error
#
# $\qquad C = \frac{1}{2N}\sum_j \left(y_j-\hat{y}_j\right)^2 = C(\alpha,\beta)$
#
# we can fit the straigth line as follows by using the design matrix $X$ and the data vector $Y$, defined by
#
# $\qquad X = \left(\begin{array}{cc} 1 & x_0 \\ 1 & x_1 \\ \vdots & \vdots \\ 1 & x_{N-1}\end{array}\right), \qquad Y = \left(\begin{array}{c} y_0\\ \vdots \\ y_{N-1}\end{array}\right)$
#
# We find
#
# $\qquad \left(\begin{array}{c}\alpha \\ \beta\end{array}\right) = \left(X^T\cdot X\right)^{-1}\cdot X^T\cdot Y$
#
# Hence, here we can easily compute the (linear) model which best fits the training data in the sense of obtaining a minimal mean square error.
#
# #### Solution of Normal Equations in Pytorch

# %%
N = x.size

# YOUR CODE (START)
# compose torch tensors X,Y of shape (N,2) and (N,1) respectively
X = torch.tensor(np.c_[np.ones(N), x], dtype=torch.float64)
Y = torch.tensor(y.reshape(N, 1), dtype=torch.float64)

# solution of normal equations, 'a' a torch tensor of shape (2,1) that contains parameters alpha and beta, which shall be optimized
a_exact = torch.zeros((2, 1), dtype=torch.float64)

# prediction
Yhat = X@a_exact

# YOUR CODE (END)

# plot
plt.plot(X[:,1],Y,"+")
plt.plot(X[:,1],Yhat,'r')
plt.xlabel("living_area")
plt.ylabel("rent_price")
print(a_exact)
# Out:
# tensor([[0.],
#         [0.]], dtype=torch.float64)

# %% [markdown]
# Note that with the pytorch function `torch.lstsq` you can obtain the same.

# %% [markdown]
# #### Cost

# %%
def cost(X,Y,a):
    # YOUR CODE (START)
    return torch.mean((Y - X @ a) ** 2)

    # YOUR CODE (END)

# %%
min_cost = cost(X,Y,a_exact)
print(min_cost)
# Out:
# tensor(1., dtype=torch.float64)

# %% [markdown]
# ### 3. Gradient Descent

# %% [markdown]
# Specify the gradient of the cost (w.r.t. $\alpha, \beta$) here as maths expression.

# %%
def gradient_cost(X,Y,a):
    # YOUR CODE (START)
    Yhat = X@a
    return X.T @ (Yhat - Y)/N
    # YOUR CODE (END)


def cost_closed_form(X: torch.Tensor, Y: torch.Tensor, a: torch.Tensor) -> torch.Tensor:
    """
    Computes the cost function J(a) using the closed-form solution for linear regression.

    Args:
        X (torch.Tensor): Feature matrix of shape (N,2)
        Y (torch.Tensor): Target values of shape (N,1)
        a (torch.Tensor): Parameter tensor of shape (2,1)

    Returns:
        torch.Tensor: Scalar tensor representing the cost value.
    """
    if not (torch.is_tensor(X) and torch.is_tensor(Y) and torch.is_tensor(a)):
        raise TypeError("Inputs X, Y, and a must be torch tensors")

    if X.dim() != 2 or Y.dim() != 2 or a.dim() != 2:
        raise ValueError("X, Y, and a must have dimensions (N,2), (N,1), and (2,1) respectively")

    if X.shape[1] != 2 or a.shape != (2, 1):
        raise ValueError("X must have shape (N,2) and a must have shape (2,1)")

    N = X.shape[0]  # Number of samples
    residuals = Y - X @ a  # Compute residuals (errors)
    cost = (1 / (2 * N)) * torch.sum(residuals ** 2)  # Compute cost
    #return torch.mean((X @ a - Y) ** 2)
    return cost

# %%
# adjust if needed
nepochs = 100
lr = 0.1

## initial parameter
a = torch.tensor([0.0,0.0], dtype=torch.float64).reshape(2,1)

# track the costs
costs = []
costsvals =[]
# YOUR CODE (START)

# loop over the epochs: update parameter values, compute the cost and add it to the costs list
for epoch in range(nepochs):
    costs.append(cost(X,Y,a))
    a -= lr * gradient_cost(X,Y,a)
    loss = cost(X, Y, a_exact)
    costsvals.append(cost(X, Y, a_exact))
    grad = gradient_cost(X, Y, a_exact)
    if epoch % 10 == 0:
        print(f"Epoch {epoch}: Loss = {loss.item()}")

costs.append(cost(X,Y,a))
    
# YOUR CODE (END)
print(costs)
# YOUR CODE (END)

# some output
cost_gd = costs[-1]
plt.plot(range(nepochs), costsvals, label='Cost per Epoch')
plt.xlabel('Epochs')
plt.ylabel('Cost')
plt.title('Cost Reduction over Time')
plt.legend()
plt.show()

plt.plot(X[:,1],Y,"+")
plt.plot(x, (X @ a).detach().numpy(), color='red', label="Regression Line")
plt.xlabel("living_area")
plt.ylabel("rent_price")
# Out:
# Epoch 0: Loss = 1.0
# Epoch 10: Loss = 1.0
# Epoch 20: Loss = 1.0
# Epoch 30: Loss = 1.0
# Epoch 40: Loss = 1.0
# Epoch 50: Loss = 1.0
# Epoch 60: Loss = 1.0
# Epoch 70: Loss = 1.0
# Epoch 80: Loss = 1.0
# Epoch 90: Loss = 1.0
# [tensor(1., dtype=torch.float64), tensor(0.8446, dtype=torch.float64), tensor(0.7188, dtype=torch.float64), tensor(0.6169, dtype=torch.float64), tensor(0.5343, dtype=torch.float64), tensor(0.4674, dtype=torch.float64), tensor(0.4133, dtype=torch.float64), tensor(0.3694, dtype=torch.float64), tensor(0.3338, dtype=torch.float64), tensor(0.3051, dtype=torch.float64), tensor(0.2817, dtype=torch.float64), tensor(0.2629, dtype=torch.float64), tensor(0.2476, dtype=torch.float64), tensor(0.2352, dtype=torch.float64), tensor(0.2251, dtype=torch.float64), tensor(0.2170, dtype=torch.float64), tensor(0.2104, dtype=torch.float64), tensor(0.2051, dtype=torch.float64), tensor(0.2008, dtype=torch.float64), tensor(0.1973, dtype=torch.float64), tensor(0.1944, dtype=torch.float64), tensor(0.1921, dtype=torch.float64), tensor(0.1903, dtype=torch.float64), tensor(0.1888, dtype=torch.float64), tensor(0.1875, dtype=torch.float64), tensor(0.1865, dtype=torch.float64), tensor(0.1857, dtype=torch.float64), tensor(0.1851, dtype=torch.float64), tensor(0.1846, dtype=torch.float64), tensor(0.1841, dtype=torch.float64), tensor(0.1838, dtype=torch.float64), tensor(0.1835, dtype=torch.float64), tensor(0.1833, dtype=torch.float64), tensor(0.1831, dtype=torch.float64), tensor(0.1830, dtype=torch.float64), tensor(0.1828, dtype=torch.float64), tensor(0.1827, dtype=torch.float64), tensor(0.1827, dtype=torch.float64), tensor(0.1826, dtype=torch.float64), tensor(0.1826, dtype=torch.float64), tensor(0.1825, dtype=torch.float64), tensor(0.1825, dtype=torch.float64), tensor(0.1825, dtype=torch.float64), tensor(0.1824, dtype=torch.float64), tensor(0.1824, dtype=torch.float64), tensor(0.1824, dtype=torch.float64), tensor(0.1824, dtype=torch.float64), tensor(0.1824, dtype=torch.float64), tensor(0.1824, dtype=torch.float64), tensor(0.1824, dtype=torch.float64), tensor(0.1824, dtype=torch.float64), tensor(0.1824, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64), tensor(0.1823, dtype=torch.float64)]
# Text(0, 0.5, 'rent_price')

# %% [markdown]
# ### 4. Different Learning Rates
#
# Play with different learning rates: Explore for what learning rates
# - the learning is most efficient
# - the learning yet works
# - the learning does not work anymore (learning rate too large)
#
# Explain the different scenarios.

# %% [markdown]
# ### 5. Use PyTorch's autograd
